# %%
import matplotlib.pyplot as plt 
import os
import json
import urllib
import pylab as pl 
import pandas as pd
import numpy as np 
import geopandas as gpd
import json
import requests
import zipfile
import io 
import shapely
import shutil
from fiona.crs import from_epsg
import seaborn as sns
import scipy as sp 
from scipy import stats

# %pylab inline

try:
    import urllib2 as urllib
except ImportError:
    import urllib.request as urllib
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
### Download of NYCHA housing polygons shapefile

url = 'https://data.cityofnewyork.us/api/geospatial/i9rv-hdr5?method=export&format=Shapefile'

print("PUIdata", os.getenv("PUIDATA"))

print('Downloading shapefile...')
r = requests.get(url)
z = zipfile.ZipFile(io.BytesIO(r.content))
print("Done")

z.extractall(path='/nfshome/mbh329/PUIdata/')

filenames = [y for y in sorted(z.namelist()) for ending in ['dbf', 'prj', 'shp', 'shx'] if y.endswith(ending)] 
print(filenames)
# Out:
# PUIdata /nfshome/mbh329/PUIdata
# Downloading shapefile...
# Done
# ['geo_export_d93a7a61-e1a8-4835-835b-a51d5eb2baa9.dbf', 'geo_export_d93a7a61-e1a8-4835-835b-a51d5eb2baa9.prj', 'geo_export_d93a7a61-e1a8-4835-835b-a51d5eb2baa9.shp', 'geo_export_d93a7a61-e1a8-4835-835b-a51d5eb2baa9.shx']

# %%
nychaloc = gpd.read_file('/nfshome/mbh329/PUIdata/nychahousing.shp')

# %%
nychaloc
# Out:
#            borough                           developmen tds_num  \
# 0          VARIOUS   FHA REPOSSESSED HOUSES (GROUP III)     213
# 1          VARIOUS    FHA REPOSSESSED HOUSES (GROUP IV)     226
# 2          VARIOUS   FHA REPOSSESSED HOUSES (GROUP VII)     274
# 3          VARIOUS  FHA REPOSSESSED HOUSES (GROUP VIII)     275
# 4          VARIOUS     FHA REPOSSESSED HOUSES (GROUP V)     260
# 5          VARIOUS    FHA REPOSSESSED HOUSES (GROUP VI)     273
# 6            BRONX         RANDALL AVENUE-BALCOM AVENUE     245
# 7    STATEN ISLAND                        NEW LANE AREA     314
# 8          VARIOUS    FHA REPOSSESSED HOUSES (GROUP IX)     283
# 9          VARIOUS     FHA REPOSSESSED HOUSES (GROUP X)     284
# 10       MANHATTAN       PUBLIC SCHOOL 139 (CONVERSION)     340
# 11        BROOKLYN                   RALPH AVENUE REHAB     352
# 12          QUEENS                           RAVENSWOOD     048
# 13        BROOKLYN                        RED HOOK EAST     004
# 14        BROOKLYN                        RED HOOK WEST     079
# 15          QUEENS                              REDFERN     055
# 16          QUEENS        REHAB PROGRAM (COLLEGE POINT)     143
# 17       MANHATTAN      REHAB PROGRAM (DOUGLASS REHABS)     515
# 18       MANHATTAN           REHAB PROGRAM (WISE REHAB)     517
# 19        BROOKLYN                      REID APARTMENTS     167
# 20       MANHATTAN                                 RIIS     018
# 21       MANHATTAN                              RIIS II     019
# 22       MANHATTAN                        ROBBINS PLAZA     218
# 23       MANHATTAN                             ROBINSON     241
# 24        BROOKLYN                      PARK ROCK REHAB     351
# 25        BROOKLYN                          ROOSEVELT I     135
# 26        BROOKLYN                         ROOSEVELT II     177
# 27       MANHATTAN                              RUTGERS     099
# 28        BROOKLYN                       RUTLAND TOWERS     282
# 29           BRONX                            SACK WERN     280
# ..             ...                                  ...     ...
# 313        VARIOUS     FHA REPOSSESSED HOUSES (GROUP I)     209
# 314        VARIOUS    FHA REPOSSESSED HOUSES (GROUP II)     212
# 315       BROOKLYN                            BOULEVARD     046
# 316  STATEN ISLAND                     RICHMOND TERRACE     117
# 317  STATEN ISLAND                      WEST BRIGHTON I     116
# 318  STATEN ISLAND                     WEST BRIGHTON II     175
# 319  STATEN ISLAND                            TODT HILL     042
# 320         QUEENS                              POMONOK     053
# 321      MANHATTAN                             RANDOLPH     278
# 322          BRONX        EAST 173RD STREET-VYSE AVENUE     338
# 323      MANHATTAN                           WASHINGTON     062
# 324          BRONX                   HIGHBRIDGE GARDENS     078
# 325          BRONX                            SOUNDVIEW     071
# 326      MANHATTAN                       SAINT NICHOLAS     038
# 327       BROOKLYN                    BORINQUEN PLAZA I     243
# 328      MANHATTAN                               WAGNER     074
# 329      MANHATTAN                  POLO GROUNDS TOWERS     149
# 330      MANHATTAN                               RANGEL     037
# 331          BRONX                          LA PRECIOSA     590
# 332          BRONX                         BOSTON SECOR     138
# 333          BRONX                    SAINT MARY'S PARK     093
# 334      MANHATTAN     MORRIS PARK SENIOR CITIZENS HOME     277
# 335      MANHATTAN          REHAB PROGRAM (TAFT REHABS)     516
# 336      MANHATTAN                       RANDOLPH SOUTH     561
# 337       BROOKLYN              PROSPECT PLAZA PHASE II     592
# 338       BROOKLYN               PROSPECT PLAZA PHASE I     591
# 339         QUEENS                   QUEENSBRIDGE NORTH     505
# 340         QUEENS                   QUEENSBRIDGE SOUTH     005
# 341       BROOKLYN                              WHITMAN     514
# 342       BROOKLYN                            INGERSOLL     014
#
#                                               geometry
# 0    (POLYGON ((-73.93559146071932 40.6594891659253...
# 1    (POLYGON ((-73.92913654009605 40.6620874071209...
# 2    (POLYGON ((-73.76955112561133 40.6615154004818...
# 3    (POLYGON ((-73.7935323517346 40.67461675600666...
# 4    (POLYGON ((-73.92285468610142 40.6560250263966...
# 5    (POLYGON ((-73.77437108469491 40.6637481196787...
# 6    POLYGON ((-73.82755659654781 40.82154582831085...
# 7    POLYGON ((-74.06069977692904 40.61306453835194...
# 8    (POLYGON ((-73.92782507256469 40.6609065142092...
# 9    (POLYGON ((-73.7889041552052 40.59074846538255...
# 10   POLYGON ((-73.94050488318011 40.81768597199684...
# 11   POLYGON ((-73.92259518803294 40.66572916091494...
# 12   (POLYGON ((-73.93574520883855 40.7612075128924...
# 13   POLYGON ((-74.00249389987998 40.67373299667823...
# 14   (POLYGON ((-74.00643088235532 40.6775611693150...
# 15   POLYGON ((-73.75208650890249 40.60843339855792...
# 16   POLYGON ((-73.84283004025734 40.78052442082863...
# 17   (POLYGON ((-73.9687317622431 40.79991047503207...
# 18   POLYGON ((-73.9676785139458 40.79079649351923,...
# 19   POLYGON ((-73.93916993754198 40.66192872427667...
# 20   (POLYGON ((-73.97238164268212 40.7260688000260...
# 21   POLYGON ((-73.97584054322758 40.72371724699431...
# 22   POLYGON ((-73.95744671660006 40.76681479020332...
# 23   POLYGON ((-73.93703084220449 40.80698005153805...
# 24   (POLYGON ((-73.92817931017701 40.6718297541995...
# 25   (POLYGON ((-73.93967703697376 40.6928203899034...
# 26   (POLYGON ((-73.93450211501418 40.6945053692854...
# 27   POLYGON ((-73.99030053236753 40.71125986956459...
# 28   POLYGON ((-73.92837386760309 40.66198144644606...
# 29   (POLYGON ((-73.86785525274171 40.8195328904296...
# ..                                                 ...
# 313  (POLYGON ((-73.74819953113064 40.6113728952574...
# 314  (POLYGON ((-73.80003676443592 40.5985081072167...
# 315  (POLYGON ((-73.87905739663081 40.6596279611743...
# 316  (POLYGON ((-74.08628175101268 40.6453550958658...
# 317  POLYGON ((-74.11982437821848 40.63533421060766...
# 318  POLYGON ((-74.12033241434868 40.63527943148902...
# 319  POLYGON ((-74.12021407697041 40.60883312937229...
# 320  (POLYGON ((-73.81097676374247 40.7322013726609...
# 321  (POLYGON ((-73.95551311273542 40.8023624422917...
# 322  (POLYGON ((-73.88809177483104 40.8334082679571...
# 323  (POLYGON ((-73.94590698637731 40.7861439475624...
# 324  POLYGON ((-73.9284139429121 40.83854097043626,...
# 325  (POLYGON ((-73.86582455466663 40.8165054790033...
# 326  (POLYGON ((-73.94676240853298 40.8115102816154...
# 327  (POLYGON ((-73.94384430552782 40.7029975405909...
# 328  (POLYGON ((-73.92980117324899 40.7971560054710...
# 329  POLYGON ((-73.93559885457438 40.83176487622417...
# 330  POLYGON ((-73.93543367804271 40.83225363619455...
# 331  POLYGON ((-73.90867166532887 40.82786386131148...
# 332  (POLYGON ((-73.83219717586559 40.8821942764708...
# 333  (POLYGON ((-73.90928526870211 40.8157993807774...
# 334  POLYGON ((-73.94159790115789 40.80566250870489...
# 335  (POLYGON ((-73.95530774649546 40.8009609274225...
# 336  POLYGON ((-73.95406153306725 40.80207789038136...
# 337  POLYGON ((-73.91870032479005 40.67304820929597...
# 338  POLYGON ((-73.916995169378 40.67240874162394, ...
# 339  (POLYGON ((-73.94145390470287 40.7552205979177...
# 340  (POLYGON ((-73.94414626771619 40.7547981915647...
# 341  (POLYGON ((-73.97609929035013 40.6940494460874...
# 342  (POLYGON ((-73.98042666705561 40.6957389847885...
#
# [343 rows x 4 columns]

# %%
nychaman = nychaloc[nychaloc["borough"]== "MANHATTAN"] #selecting only manhattan

# %%
nychaman
# Out:
#        borough                             developmen tds_num  \
# 10   MANHATTAN         PUBLIC SCHOOL 139 (CONVERSION)     340
# 17   MANHATTAN        REHAB PROGRAM (DOUGLASS REHABS)     515
# 18   MANHATTAN             REHAB PROGRAM (WISE REHAB)     517
# 20   MANHATTAN                                   RIIS     018
# 21   MANHATTAN                                RIIS II     019
# 22   MANHATTAN                          ROBBINS PLAZA     218
# 23   MANHATTAN                               ROBINSON     241
# 27   MANHATTAN                                RUTGERS     099
# 33   MANHATTAN                          SAMUEL (CITY)     377
# 34   MANHATTAN                        SAMUEL (MHOP) I     389
# 35   MANHATTAN                       SAMUEL (MHOP) II     398
# 36   MANHATTAN                      SAMUEL (MHOP) III     399
# 23   POLYGON ((-73.93703084220449 40.80698005153805...
# 27   POLYGON ((-73.99030053236753 40.71125986956459...
# 33   (POLYGON ((-73.93908471289893 40.8203535586144...
# 34   (POLYGON ((-73.94071899966191 40.8183847669019...
# 35   POLYGON ((-73.94021790239466 40.81675395787843...
# 36   POLYGON ((-73.93950354321296 40.81971744599259...
# 38   (POLYGON ((-73.98840931723313 40.7166391415242...
# 41   POLYGON ((-73.99817596881157 40.71049408932928...
# 44   POLYGON ((-73.98354780102281 40.71958622561776...
# 48   (POLYGON ((-73.97954576906965 40.7410136381883...
# 51   POLYGON ((-73.97071449112306 40.78966385832555...
# 57   (POLYGON ((-73.94569179090448 40.7990862179363...
# 65   POLYGON ((-73.98598006885344 40.71119109279839...
# 77   POLYGON ((-74.00172849817793 40.74903674559263...
# 78   POLYGON ((-74.00184418768299 40.7493143410048,...
# 86   (POLYGON ((-73.94460961905325 40.7947739965842...
# 94   POLYGON ((-73.93719201427018 40.79699864892021...
# 99   POLYGON ((-73.97247875033277 40.79269735155462...
# 100  POLYGON ((-73.9682086318563 40.79855310204776,...
# 101  (POLYGON ((-73.96265807083145 40.7972958494361...
# 102  POLYGON ((-73.96736600386924 40.79784563678802...
# 103  (POLYGON ((-73.9402675021343 40.82036442774922...
# 104  POLYGON ((-73.92149411551034 40.86261750159792...
# 111  POLYGON ((-73.93933149095291 40.78645370059659...
# ..                                                 ...
# 237  POLYGON ((-73.98729607283968 40.77365083663782...
# 238  POLYGON ((-73.98724637220094 40.77503796108164...
# 245  POLYGON ((-73.94260711605085 40.83094069234913...
# 248  POLYGON ((-73.98035592924955 40.71653640576481...
# 249  POLYGON ((-73.97955187447903 40.71698486839207...
# 266  POLYGON ((-73.94134140842566 40.8316549673097,...
# 271  POLYGON ((-73.98125789000385 40.72264202692026...
# 272  POLYGON ((-73.95366285971959 40.80416073128124...
# 280  POLYGON ((-73.94441677908047 40.79017264020117...
# 288  POLYGON ((-73.97630274182364 40.72787534722057...
# 292  (POLYGON ((-73.9334995559224 40.84569612014525...
# 293  (POLYGON ((-73.93768605168331 40.8371519808318...
# 294  POLYGON ((-73.94424573399854 40.83338176453192...
# 295  (POLYGON ((-73.9339658521984 40.84504553804568...
# 296  POLYGON ((-73.93407035665498 40.84514467723389...
# 303  POLYGON ((-73.93999741341432 40.7894657561656,...
# 304  POLYGON ((-73.97244612702723 40.79005889820834...
# 307  (POLYGON ((-73.96785258217557 40.7887303713215...
# 308  POLYGON ((-73.97024711276708 40.79188621623415...
# 309  POLYGON ((-73.96922438292366 40.78950887030236...
# 310  POLYGON ((-73.97314768495586 40.78932962673809...
# 321  (POLYGON ((-73.95551311273542 40.8023624422917...
# 323  (POLYGON ((-73.94590698637731 40.7861439475624...
# 326  (POLYGON ((-73.94676240853298 40.8115102816154...
# 328  (POLYGON ((-73.92980117324899 40.7971560054710...
# 329  POLYGON ((-73.93559885457438 40.83176487622417...
# 330  POLYGON ((-73.93543367804271 40.83225363619455...
# 334  POLYGON ((-73.94159790115789 40.80566250870489...
# 2   POLYGON ((-73.97139631688152 40.64825778611409...
# 3   POLYGON ((-73.89646625062909 40.68233642247531...
# 4   POLYGON ((-73.83979488496 40.8356192074919, -7...
# 5   POLYGON ((-73.8718461029101 40.84376077785579,...
# 6   POLYGON ((-73.89663333863315 40.91141737484628...
# 7   POLYGON ((-73.79385527209071 40.88364331133348...
# 8   POLYGON ((-73.86789798628736 40.90294017690526...
# 9   POLYGON ((-73.90755209573506 40.65118592573071...
# 10  POLYGON ((-73.92872204594657 40.66449556918268...
# 11  POLYGON ((-74.00174362111041 40.69240674970546...
# 12  POLYGON ((-73.84750820344139 40.73900780704004...
# 13  (POLYGON ((-73.91192551843878 40.5658138623766...
# 14  POLYGON ((-73.82834347497577 40.86089202667581...
# 15  POLYGON ((-73.86275490196977 40.76676452492579...
# 16  (POLYGON ((-73.91513331918196 40.5862693854006...
# 17  POLYGON ((-73.92405909736993 40.71411156014749...
# 18  POLYGON ((-73.897923512633 40.75424000267809, ...
# 19  POLYGON ((-73.87053738652396 40.86967403141296...
# 20  POLYGON ((-73.90404639808888 40.67922059801916...
# 21  POLYGON ((-73.80168266553363 40.6663223525709,...
# 22  POLYGON ((-73.88770199204359 40.73429132275795...
# 23  POLYGON ((-73.89138023380261 40.86170058826304...
# 24  POLYGON ((-73.835900721417 40.71164137076879, ...
# 25  POLYGON ((-73.91809256480775 40.58657033550732...
# 26  (POLYGON ((-73.90647314610101 40.7901811752080...
# 27  (POLYGON ((-74.13319580101383 40.5363067420505...
# 28  POLYGON ((-73.87518850162601 40.87157575681208...
# 29  POLYGON ((-73.97301487176121 40.76427887944521...
# ..                                                ...
# 41  POLYGON ((-73.746943206382 40.63752920217698, ...
# 42  POLYGON ((-74.03231084300101 40.64403921448037...
# 43  (POLYGON ((-74.15945602438185 40.6414483333240...
# 44  POLYGON ((-73.81709738756452 40.70402980158765...
# 45  (POLYGON ((-73.78833349834532 40.8346671297593...
# 46  (POLYGON ((-73.77460156350934 40.8620690474597...
# 47  POLYGON ((-73.86275490196977 40.76676452492579...
# 48  POLYGON ((-73.93445239397371 40.83598096014986...
# 49  (POLYGON ((-73.83970053428534 40.7652895884376...
# 50  POLYGON ((-73.71351828105992 40.7598377308308,...
# 51  (POLYGON ((-73.92133752419279 40.8008521075021...
# 52  POLYGON ((-73.90129277627106 40.82047544211161...
# 53  POLYGON ((-73.93445239397371 40.83598096014986...
# 54  (POLYGON ((-73.89680883223774 40.7958084451597...
# 55  POLYGON ((-73.88072081514281 40.83752126451973...
# 56  POLYGON ((-73.98877931684075 40.73396539973847...
# 57  POLYGON ((-73.9968399392649 40.7373608893982, ...
# 58  POLYGON ((-73.99393694248319 40.77317951096692...
# 59  POLYGON ((-73.94923327082499 40.79687199990541...
# 60  POLYGON ((-73.95964685423152 40.80115642325645...
# 61  POLYGON ((-73.94014131210091 40.83037198888071...
# 62  (POLYGON ((-73.96134684652041 40.7301524727151...
# 63  (POLYGON ((-73.94180032729426 40.7690469266246...
# 64  POLYGON ((-73.8260230362221 40.71540835206951,...
# 65  POLYGON ((-73.7567032923354 40.72622943266181,...
# 66  POLYGON ((-73.83591564941864 40.74343089389602...
# 67  (POLYGON ((-73.91236790288811 40.5845261742472...
# 68  (POLYGON ((-73.93176252156162 40.5578796380419...
# 69  (POLYGON ((-74.07346627066256 40.5783856858973...
# 70  (POLYGON ((-74.11834169292992 40.5504596952958...
#
# [71 rows x 4 columns]

# %%
comdis['boro_cd'] = comdis['boro_cd'].astype(int) #switch float to interger

# %%
comdis1 = [101, 102, 103, 104, 105, 106, 107, 108, 109, 110, 111, 112]

comdis_man = comdis[comdis['boro_cd'].apply(lambda x: x in comdis1)]

# %%
comdis_man #boro_cd is the community district number +1__
# Out:
#     boro_cd    shape_area    shape_leng  \
# 29      105  4.379030e+07  35288.305061
# 39      101  4.267503e+07  73785.483824
# 48      110  3.908463e+07  35825.290700
# 51      111  6.614601e+07  59502.909391
# 53      112  7.796661e+07  56219.763159
# 56      103  4.687970e+07  30468.340658
# 57      102  3.772316e+07  34902.880915
# 58      104  4.929234e+07  67941.137396
# 60      107  5.315282e+07  39863.701384
# 61      109  4.189218e+07  34959.184938
# 62      106  3.872857e+07  42672.566588
# 63      108  5.516880e+07  53561.096775
#
#                                              geometry
# 29  POLYGON ((-73.97301487176121 40.76427887944521...
# 39  (POLYGON ((-74.0438776163991 40.69018767537123...
# 48  POLYGON ((-73.93445239397371 40.83598096014986...
# 51  (POLYGON ((-73.92133752419279 40.8008521075021...
# 53  POLYGON ((-73.93445239397371 40.83598096014986...
# 56  POLYGON ((-73.98877931684075 40.73396539973847...
# 57  POLYGON ((-73.9968399392649 40.7373608893982, ...
# 58  POLYGON ((-73.99393694248319 40.77317951096692...
# 60  POLYGON ((-73.95964685423152 40.80115642325645...
# 61  POLYGON ((-73.94014131210091 40.83037198888071...
# 62  (POLYGON ((-73.96134684652041 40.7301524727151...
# 63  (POLYGON ((-73.94180032729426 40.7690469266246...

# %%
### making sure all gpd are in the correct projection

comdis_man.to_crs(epsg=4326)

nychaman.to_crs(epsg=4326)


# boros.to_crs(epsg=2263)
# Out:
#        borough                             developmen tds_num  \
# 10   MANHATTAN         PUBLIC SCHOOL 139 (CONVERSION)     340
# 17   MANHATTAN        REHAB PROGRAM (DOUGLASS REHABS)     515
# 18   MANHATTAN             REHAB PROGRAM (WISE REHAB)     517
# 20   MANHATTAN                                   RIIS     018
# 21   MANHATTAN                                RIIS II     019
# 22   MANHATTAN                          ROBBINS PLAZA     218
# 23   MANHATTAN                               ROBINSON     241
# 27   MANHATTAN                                RUTGERS     099
# 33   MANHATTAN                          SAMUEL (CITY)     377
# 34   MANHATTAN                        SAMUEL (MHOP) I     389
# 35   MANHATTAN                       SAMUEL (MHOP) II     398
# 36   MANHATTAN                      SAMUEL (MHOP) III     399
# 38   MANHATTAN                  SEWARD PARK EXTENSION     192
# 41   MANHATTAN                                  SMITH     027
# 44   MANHATTAN                         STANTON STREET     559
# 48   MANHATTAN                                 STRAUS     153
# 51   MANHATTAN                      THOMAS APARTMENTS     268
# 57   MANHATTAN                                   TAFT     097
# 65   MANHATTAN               TWO BRIDGES URA (SITE 7)     266
# 38   (POLYGON ((-73.98840931723313 40.7166391415242...
# 41   POLYGON ((-73.99817596881157 40.71049408932928...
# 44   POLYGON ((-73.98354780102281 40.71958622561776...
# 48   (POLYGON ((-73.97954576906965 40.7410136381883...
# 51   POLYGON ((-73.97071449112306 40.78966385832555...
# 57   (POLYGON ((-73.94569179090448 40.7990862179363...
# 65   POLYGON ((-73.98598006885344 40.71119109279839...
# 77   POLYGON ((-74.00172849817793 40.74903674559263...
# 78   POLYGON ((-74.00184418768299 40.7493143410048,...
# 86   (POLYGON ((-73.94460961905325 40.7947739965842...
# 94   POLYGON ((-73.93719201427018 40.79699864892021...
# 99   POLYGON ((-73.97247875033277 40.79269735155462...
# 100  POLYGON ((-73.9682086318563 40.79855310204776,...
# 101  (POLYGON ((-73.96265807083145 40.7972958494361...
# 102  POLYGON ((-73.96736600386924 40.79784563678802...
# 103  (POLYGON ((-73.9402675021343 40.82036442774922...
# 104  POLYGON ((-73.92149411551034 40.86261750159792...
# 111  POLYGON ((-73.93933149095291 40.78645370059659...
# ..                                                 ...
# 237  POLYGON ((-73.98729607283968 40.77365083663782...
# 238  POLYGON ((-73.98724637220094 40.77503796108164...
# 245  POLYGON ((-73.94260711605085 40.83094069234913...
# 248  POLYGON ((-73.98035592924955 40.71653640576481...
# 249  POLYGON ((-73.97955187447903 40.71698486839207...
# 266  POLYGON ((-73.94134140842566 40.8316549673097,...
# 271  POLYGON ((-73.98125789000385 40.72264202692026...
# 272  POLYGON ((-73.95366285971959 40.80416073128124...
# 280  POLYGON ((-73.94441677908047 40.79017264020117...
# 288  POLYGON ((-73.97630274182364 40.72787534722057...
# 292  (POLYGON ((-73.9334995559224 40.84569612014525...
# 293  (POLYGON ((-73.93768605168331 40.8371519808318...
# 294  POLYGON ((-73.94424573399854 40.83338176453192...
# 295  (POLYGON ((-73.9339658521984 40.84504553804568...
# 296  POLYGON ((-73.93407035665498 40.84514467723389...
# 303  POLYGON ((-73.93999741341432 40.7894657561656,...
# 304  POLYGON ((-73.97244612702723 40.79005889820834...
# 307  (POLYGON ((-73.96785258217557 40.7887303713215...
# 308  POLYGON ((-73.97024711276708 40.79188621623415...
# 309  POLYGON ((-73.96922438292366 40.78950887030236...
# 310  POLYGON ((-73.97314768495586 40.78932962673809...
# 321  (POLYGON ((-73.95551311273542 40.8023624422917...
# 323  (POLYGON ((-73.94590698637731 40.7861439475624...
# 326  (POLYGON ((-73.94676240853298 40.8115102816154...
# 328  (POLYGON ((-73.92980117324899 40.7971560054710...
# 329  POLYGON ((-73.93559885457439 40.83176487622417...
# 330  POLYGON ((-73.93543367804271 40.83225363619455...
# 334  POLYGON ((-73.94159790115789 40.80566250870489...
# 335  (POLYGON ((-73.95530774649546 40.8009609274225...
# 336  POLYGON ((-73.95406153306725 40.80207789038136...
#
# [104 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize  = (13, 13))

ax.set_title("NYCHA Housing Locations within Community Distric Boundaries in Manhattan", fontsize=15)

ax.get_xaxis().set_visible(False) #takes away axis from the map x,y axis relates to Lat, Long 
ax.get_yaxis().set_visible(False) #latitude

#man.plot(color="white", alpha=1, edgecolor='black', ax=ax)
#manhattan boro plot

#boros.plot(color="white", alpha=1, edgecolor="black", ax=ax)
#all 5 boros

comdis_man.plot(column='boro_cd', color="white", alpha=1, edgecolor="black", legend=True, k=9, lw=.5, ax=ax)
#council districts

nychaman.plot(color="blue", alpha=1, edgecolor="blue", ax=ax)
#nycha housing
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/geopandas/plotting.py:389: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
nychaman['geometry'].to_crs({'init': 'epsg:3395'})\
               .map(lambda p: p.area)
# Out:
# 10      10040.627499
# 17       3867.901240
# 18       1648.952468
# 20      81097.759044
# 21      41230.403959
# 22       1997.777926
# 23       9833.935825
# 27      35670.816049
# 33      32173.974305
# 34       2169.342232
# 35        468.911280
# 36        914.536649
# 38      14401.386508
# 41     127136.536211
# 44        776.689491
# 48       7185.875644
# 51       1430.015825
# 57      83378.043400
# 65       5051.140642
# 77      12711.540034
# 78       7139.305892
# 86      37381.174042
# 94       5093.956466
# 99       5345.994762
# 100      3842.529205
# 101     81735.131455
# 102     57859.306121
# 103     48295.390286
# 104     90423.884712
# 111     77183.491457
#            ...
# 237     69516.282785
# 238      6019.194129
# 245      3879.354441
# 248    185841.663460
# 249      3351.450224
# 266      9921.758770
# 271      6996.201453
# 272      4466.223561
# 280      5711.756257
# 288     13220.065724
# 292      9028.659190
# 293      3914.357310
# 294       655.918678
# 295      1357.750274
# 296      1398.441520
# 303     21099.212511
# 304     15371.097621
# 307     10816.094969
# 308      3742.345633
# 309      3924.387526
# 310      3863.617999
# 321      6926.356205
# 323    140396.871032
# 326    101827.056948
# 328    175748.166399
# 329    106364.820411
# 330     76374.928275
# 334      1651.717071
# 335      4429.047852
# 336      9795.312821
# Name: geometry, dtype: float64

# %%
nychaman['newarea'] = nychaman['geometry'].to_crs({'init': 'epsg:3395'})\
               .map(lambda p: p.area)
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
nychaman.head(5)
# Out:
#       borough                       developmen tds_num  \
# 10  MANHATTAN   PUBLIC SCHOOL 139 (CONVERSION)     340
# 17  MANHATTAN  REHAB PROGRAM (DOUGLASS REHABS)     515
# 18  MANHATTAN       REHAB PROGRAM (WISE REHAB)     517
# 20  MANHATTAN                             RIIS     018
# 21  MANHATTAN                          RIIS II     019
#
#                                              geometry       newarea
# 10  POLYGON ((-73.94050488318011 40.81768597199684...  10040.627499
# 17  (POLYGON ((-73.9687317622431 40.79991047503207...   3867.901240
# 18  POLYGON ((-73.9676785139458 40.79079649351923,...   1648.952468
# 20  (POLYGON ((-73.97238164268212 40.7260688000260...  81097.759044
# 21  POLYGON ((-73.97584054322758 40.72371724699431...  41230.403959

# %%
comdis_man
# Out:
#     boro_cd    shape_area    shape_leng  \
# 29      105  4.379030e+07  35288.305061
# 39      101  4.267503e+07  73785.483824
# 48      110  3.908463e+07  35825.290700
# 51      111  6.614601e+07  59502.909391
# 53      112  7.796661e+07  56219.763159
# 56      103  4.687970e+07  30468.340658
# 57      102  3.772316e+07  34902.880915
# 58      104  4.929234e+07  67941.137396
# 60      107  5.315282e+07  39863.701384
# 61      109  4.189218e+07  34959.184938
# 62      106  3.872857e+07  42672.566588
# 63      108  5.516880e+07  53561.096775
#
#                                              geometry
# 29  POLYGON ((-73.97301487176121 40.76427887944521...
# 39  (POLYGON ((-74.0438776163991 40.69018767537123...
# 48  POLYGON ((-73.93445239397371 40.83598096014986...
# 51  (POLYGON ((-73.92133752419279 40.8008521075021...
# 53  POLYGON ((-73.93445239397371 40.83598096014986...
# 56  POLYGON ((-73.98877931684075 40.73396539973847...
# 57  POLYGON ((-73.9968399392649 40.7373608893982, ...
# 58  POLYGON ((-73.99393694248319 40.77317951096692...
# 60  POLYGON ((-73.95964685423152 40.80115642325645...
# 61  POLYGON ((-73.94014131210091 40.83037198888071...
# 62  (POLYGON ((-73.96134684652041 40.7301524727151...
# 63  (POLYGON ((-73.94180032729426 40.7690469266246...

# %%
nychousing = gpd.sjoin(comdis_man, nychaman)

nychousing.head()
# Out:
#     boro_cd    shape_area  shape_leng  \
# 48      110  3.908463e+07  35825.2907
# 48      110  3.908463e+07  35825.2907
# 48      110  3.908463e+07  35825.2907
# 48      110  3.908463e+07  35825.2907
# 48      110  3.908463e+07  35825.2907
#
#                                              geometry  index_right    borough  \
# 48  POLYGON ((-73.93445239397371 40.83598096014986...          336  MANHATTAN
# 48  POLYGON ((-73.93445239397371 40.83598096014986...          335  MANHATTAN
# 48  POLYGON ((-73.93445239397371 40.83598096014986...          321  MANHATTAN
# 48  POLYGON ((-73.93445239397371 40.83598096014986...          272  MANHATTAN
# 48  POLYGON ((-73.93445239397371 40.83598096014986...          134  MANHATTAN
#
#                      developmen tds_num      newarea
# 48               RANDOLPH SOUTH     561  9795.312821
# 48  REHAB PROGRAM (TAFT REHABS)     516  4429.047852
# 48                     RANDOLPH     278  6926.356205
# 48    131 SAINT NICHOLAS AVENUE     154  4466.223561
# 48                     GRAMPION     281  1095.384694

# %%
fig, ax = plt.subplots(figsize  = (10, 10))

ax.set_title("Percentage of NYCHA Housing by area within Community District Boundaries in Manhattan", fontsize=15)

ax.get_xaxis().set_visible(False) #takes away axis from the map x,y axis relates to Lat, Long 
ax.get_yaxis().set_visible(False) #latitude


comdis_man.plot(column='boro_cd', color="white", alpha=1, edgecolor="black", lw=.2, ax=ax)
#council districts

nychousing.plot(cmap='hot',alpha=1,linewidth=0.2,ax=ax, legend=True, scheme="Equal_Interval", k=7)


nychaman.plot(color="blue", alpha=1, lw=.2, edgecolor="blue", ax=ax)

plt.show()
# Out:
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/geopandas/plotting.py:389: UserWarning: Only specify one of 'column' or 'color'. Using 'color'.
#   "'color'.", UserWarning)
# /usr/local/Anaconda3-5.0.0-Linux-x86_64/envs/PUI2016_Python3/lib/python3.5/site-packages/matplotlib/font_manager.py:1316: UserWarning: findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# ### Figure 1: This choropleth map shows the percentage (by area) of NYCHA owned property within Community Districts. The darker the color scheme, the higher percentage of NYCHA housing by area. Overlayed on top (in blue) is the location polygons of actual NYCHA property.

# %%
# comdis_man['geometry'].to_crs({'init': 'epsg:3395'})\
#               .map(lambda p: p.area)
